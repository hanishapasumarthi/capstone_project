# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings('ignore')

# %%
df1=pd.read_csv('Hotel_info_1.csv')
df2=pd.read_csv('Hotel_facilities_1.csv')
df3=pd.read_csv('Hotel_room_type_1.csv')

# %%
df1.head()
# Out:
#    Unnamed: 0  S_no                                       Hotel_name Cities  \
# 0           0     1                            Five Jumeirah Village  Dubai
# 1           1     2          Premier Inn Dubai International Airport  Dubai
# 2           2     3  Holiday Inn Express Dubai Airport, an IHG Hotel  Dubai
# 3           3     4                            TRYP by Wyndham Dubai  Dubai
# 4           4     5                             Wyndham Dubai Marina  Dubai
#
#                                             Location  No_of_reviews  \
# 0  Jumeirah Village Circle Dubai, Dubai, United A...          38510
# 1  52B Street, Opposite Terminal 3, Garhoud, Duba...          15925
# 2  Airport Road, Garhoud, 35257 Dubai, United Ara...          16253
# 3  Al Saef 1 Street Barsha Heights, Barsha Height...          16778
# 4  P.O. Box: 215373, Al Seba Street,, Dubai Marin...          13131
#
#    User_ratings  Star_Rating Review_score
# 0           9.3          9.1       Superb
# ...

# %%
df1.drop(columns=['Unnamed: 0','S_no'],inplace=True)
df1
# Out:
#                                            Hotel_name   Cities  \
# 0                               Five Jumeirah Village    Dubai
# 1             Premier Inn Dubai International Airport    Dubai
# 2     Holiday Inn Express Dubai Airport, an IHG Hotel    Dubai
# 3                               TRYP by Wyndham Dubai    Dubai
# 4                                Wyndham Dubai Marina    Dubai
# ..                                                ...      ...
# 95                            Woodbine Hotel & Suites  Toronto
# 96                                Pan Pacific Toronto  Toronto
# 97           Doubletree by Hilton Toronto Airport, ON  Toronto
# 98  Holiday Inn Toronto International Airport, an ...  Toronto
# 99  Best Western Plus Toronto North York Hotel & S...  Toronto
#
#                                              Location  No_of_reviews  \
# 0   Jumeirah Village Circle Dubai, Dubai, United A...          38510
# ...

# %%
df2.head()
# Out:
#    Unnamed: 0  S_no                                       Hotel_name  \
# 0           0     1                            Five Jumeirah Village
# 1           1     2          Premier Inn Dubai International Airport
# 2           2     3  Holiday Inn Express Dubai Airport, an IHG Hotel
# 3           3     4                            TRYP by Wyndham Dubai
# 4           4     5                             Wyndham Dubai Marina
#
#   Restaurant  Bar Heating Lift Breakfast_Cuisine1   Breakfast_Cuisine2  \
# 0        Yes  Yes     Yes  Yes        Continental              Italian
# 1        Yes  Yes      No  Yes        Continental   Full English/Irish
# 2        Yes  Yes      No  Yes        Continental              Italian
# 3        Yes  Yes      No  Yes                 No                   No
# 4        Yes  Yes      No  Yes        Continental           Vegetarian
#
#     Breakfast_Cuisine3 Free_wifi Family_rooms Non-smoking rooms
# ...

# %%
df2.drop(columns=['Unnamed: 0','S_no'],inplace=True)
df2
# Out:
#                                            Hotel_name Restaurant  Bar Heating  \
# 0                               Five Jumeirah Village        Yes  Yes     Yes
# 1             Premier Inn Dubai International Airport        Yes  Yes      No
# 2     Holiday Inn Express Dubai Airport, an IHG Hotel        Yes  Yes      No
# 3                               TRYP by Wyndham Dubai        Yes  Yes      No
# 4                                Wyndham Dubai Marina        Yes  Yes      No
# ..                                                ...        ...  ...     ...
# 95                            Woodbine Hotel & Suites         No   No     Yes
# 96                                Pan Pacific Toronto        Yes  Yes     Yes
# 97           Doubletree by Hilton Toronto Airport, ON        Yes  Yes     Yes
# 98  Holiday Inn Toronto International Airport, an ...        Yes  Yes     Yes
# 99  Best Western Plus Toronto North York Hotel & S...        Yes   No     Yes
#
# ...

# %%
df3.head()
# Out:
#    Unnamed: 0  S_no             Hotel_name  \
# 0           0     1  Five Jumeirah Village
# 1           1     2  Five Jumeirah Village
# 2           2     3  Five Jumeirah Village
# 3           3     4  Five Jumeirah Village
# 4           4     5  Five Jumeirah Village
#
#                                Room_Type Single_Bed Double_Bed  Price
# 0        Superior King Room with Balcony         No        Yes  14271
# 1      Superior Double Room with Balcony         No        Yes  14271
# 2         Superior Sky Room with Balcony         No        Yes  15291
# 3  Superior Sky Double Room with Balcony         No        Yes  15291
# 4              Master Suite with Hot Tub         No        Yes  21407

# %%
df3.drop(columns=['Unnamed: 0','S_no'],inplace=True)

# %%
df3
# Out:
#                                             Hotel_name  \
# 0                                Five Jumeirah Village
# 1                                Five Jumeirah Village
# 2                                Five Jumeirah Village
# 3                                Five Jumeirah Village
# 4                                Five Jumeirah Village
# ..                                                 ...
# 430           Doubletree by Hilton Toronto Airport, ON
# 431           Doubletree by Hilton Toronto Airport, ON
# 432           Doubletree by Hilton Toronto Airport, ON
# 433  Holiday Inn Toronto International Airport, an ...
# 434  Holiday Inn Toronto International Airport, an ...
#
#                                              Room_Type Single_Bed Double_Bed  \
# 0                      Superior King Room with Balcony         No        Yes
# 1                    Superior Double Room with Balcony         No        Yes
# ...

# %%
df=pd.merge(df1,df2,on=['Hotel_name'])
df
# Out:
#                                            Hotel_name   Cities  \
# 0                               Five Jumeirah Village    Dubai
# 1             Premier Inn Dubai International Airport    Dubai
# 2     Holiday Inn Express Dubai Airport, an IHG Hotel    Dubai
# 3                               TRYP by Wyndham Dubai    Dubai
# 4                                Wyndham Dubai Marina    Dubai
# ..                                                ...      ...
# 94                            Woodbine Hotel & Suites  Toronto
# 95                                Pan Pacific Toronto  Toronto
# 96           Doubletree by Hilton Toronto Airport, ON  Toronto
# 97  Holiday Inn Toronto International Airport, an ...  Toronto
# 98  Best Western Plus Toronto North York Hotel & S...  Toronto
#
#                                              Location  No_of_reviews  \
# 0   Jumeirah Village Circle Dubai, Dubai, United A...          38510
# ...

# %%
df=pd.merge(df,df3,on='Hotel_name')
df
# Out:
#                                             Hotel_name   Cities  \
# 0                                Five Jumeirah Village    Dubai
# 1                                Five Jumeirah Village    Dubai
# 2                                Five Jumeirah Village    Dubai
# 3                                Five Jumeirah Village    Dubai
# 4                                Five Jumeirah Village    Dubai
# ..                                                 ...      ...
# 421           Doubletree by Hilton Toronto Airport, ON  Toronto
# 422           Doubletree by Hilton Toronto Airport, ON  Toronto
# 423           Doubletree by Hilton Toronto Airport, ON  Toronto
# 424  Holiday Inn Toronto International Airport, an ...  Toronto
# 425  Holiday Inn Toronto International Airport, an ...  Toronto
#
#                                               Location  No_of_reviews  \
# 0    Jumeirah Village Circle Dubai, Dubai, United A...          38510
# ...

# %%
df.columns
# Out:
# Index(['Hotel_name', 'Cities', 'Location', 'No_of_reviews', 'User_ratings',
#        'Star_Rating', 'Review_score', 'Restaurant', 'Bar', 'Heating', 'Lift',
#        'Breakfast_Cuisine1', 'Breakfast_Cuisine2', 'Breakfast_Cuisine3',
#        'Free_wifi', 'Family_rooms', 'Non-smoking rooms', 'Room_Type',
#        'Single_Bed', 'Double_Bed', 'Price'],
#       dtype='object')

# %%
df.shape
# Out:
# (426, 21)

# %% [markdown]
# This dataset contains 426 records and 21 features.

# %%
df['Hotel_name'].unique()
# Out:
# array(['Five Jumeirah Village', 'Premier Inn Dubai International Airport',
#        'Holiday Inn Express Dubai Airport, an IHG Hotel',
#        'TRYP by Wyndham Dubai', 'Wyndham Dubai Marina',
#        'Millennium Airport Hotel Dubai', 'Flora Inn Hotel Dubai Airport',
#        'Citymax Hotel Bur Dubai', 'Hyatt Regency Dubai Creek Heights',
#        'Atana Hotel', 'Britannia International Hotel Canary Wharf',
#        'Zedwell Piccadilly Circus', 'Central Park Hotel',
#        'Millennium Gloucester Hotel London',
#        'DoubleTree by Hilton Hotel London - Tower of London',
#        'Intercontinental London - The O2, an IHG Hotel', 'Komune Living',
#        'Seri Pacific Hotel Kuala Lumpur', 'Dorsett Hartamas Kuala Lumpur',
#        'Hotel Sentral KL @ KL Sentral Station',
#        'Sunway Putra Hotel Kuala Lumpur', 'Traders Hotel, Kuala Lumpur',
#        'Mandarin Oriental, Kuala Lumpur',
#        'Pullman Kuala Lumpur City Centre Hotel & Residences',
# ...

# %%
df['Room_Type'].unique()
# Out:
# array(['Superior King Room with Balcony',
#        'Superior Double Room with Balcony',
#        'Superior Sky Room with Balcony',
#        'Superior Sky Double Room with Balcony',
#        'Master Suite with Hot Tub', '2 Bed Sky Villa With Private Pool',
#        '4 Bed Sky Villa With Private Pool', 'Family Room ',
#        'Double Room ',
#        'Double Room Free Shuttle Bus to Airport Terminal 1&3, Al Mamzar Beach, DFC Mall, Dubai Mall)',
#        'Standard Double Room (Free Shuttle Bus to Airport Terminal 1&3, Al Mamzar Beach, DFC Mall, Dubai Mall))',
#        'Standard Twin Room (Free Shuttle Bus to Airport Terminal 1&3, Al Mamzar Beach, DFC Mall, Dubai Mall))',
#        'King Room with Airport View (Free Shuttle Bus to Airport Terminal 1&3, Al Mamzar Beach, DFC Mall, Dubai Mall))',
#        'Tryp Room', '1 King Bed, TRYP Room with Balcony',
#        'TRYP Premium Suite', 'Superior King Room', 'Club Room',
# ...

# %%
df['Cities'].unique()
# Out:
# array(['Dubai', 'London', 'Kuala Lumpur', 'New Delhi', 'Berlin', 'Sydney',
#        'Melbourne', 'Paris', 'Tokyo', 'Toronto'], dtype=object)

# %%
df['Family_rooms'].unique()
# Out:
# array(['Yes', 'No'], dtype=object)

# %%
df['Restaurant'].unique()
# Out:
# array(['Yes', 'No'], dtype=object)

# %%
df['Bar'].unique()
# Out:
# array(['Yes', 'No'], dtype=object)

# %%
df['Heating'].unique()
# Out:
# array(['Yes', 'No'], dtype=object)

# %%
df['Lift'].unique()
# Out:
# array(['Yes', 'No'], dtype=object)

# %%
df['Breakfast_Cuisine1'].unique()
# Out:
# array(['Continental', 'No', 'Italian', 'Full English/Irish', 'Vegetarian',
#        'Buffet', 'American'], dtype=object)

# %%
df['Breakfast_Cuisine2'].unique()
# Out:
# array([' Italian', ' Full English/Irish', 'No', ' Vegetarian', ' Halal',
#        ' Asian', ' Vegan', ' American', ' Buffet', ' Gluten-free'],
#       dtype=object)

# %%
df['Breakfast_Cuisine3'].unique()
# Out:
# array([' Full English/Irish', ' Halal', ' Vegetarian', 'No',
#        ' Gluten-free', ' American', ' Asian', ' Vegan'], dtype=object)

# %%
df['Free_wifi'].unique()
# Out:
# array(['Yes', 'No'], dtype=object)

# %%
df['Heating'].unique()
# Out:
# array(['Yes', 'No'], dtype=object)

# %%
df['Non-smoking rooms'].unique()
# Out:
# array(['Yes', 'No'], dtype=object)

# %%
df['Single_Bed'].unique()
# Out:
# array(['No', 'Yes'], dtype=object)

# %%
df['Double_Bed'].unique()
# Out:
# array(['Yes', 'No'], dtype=object)

# %%
df['Review_score'].unique()
# Out:
# array(['Superb', 'Very good', 'Good', 'Pleasant', 'Passable', 'Fabulous'],
#       dtype=object)

# %% [markdown]
# From the above we can observe 'Family_rooms', 'Restaurant', 'Bar', 'Heating', 'Lift', 'Breakfast_Cuisine1', 'Breakfast_Cuisine2',
# 'Breakfast_Cuisine3', 'Free_wifi', 'Non_smoking_rooms', 'Single_bed', 'Double_bed' features as classification data. These features contains Yes and No values.

# %% [markdown]
# Let's check for Null values in the dataset.

# %%
df.isnull().sum()
# Out:
# Hotel_name            0
# Cities                0
# Location              0
# No_of_reviews         0
# User_ratings          0
# Star_Rating           0
# Review_score          0
# Restaurant            0
# Bar                   0
# Heating               0
# Lift                  0
# Breakfast_Cuisine1    0
# Breakfast_Cuisine2    0
# Breakfast_Cuisine3    0
# Free_wifi             0
# Family_rooms          0
# Non-smoking rooms     0
# Room_Type             0
# Single_Bed            0
# Double_Bed            0
# Price                 0
# dtype: int64

# %% [markdown]
# This dataset does not contain null values.

# %% [markdown]
# Let's check for duplicates in the dataset.

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# Duplicate records are not present in the dataset.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 426 entries, 0 to 425
# Data columns (total 21 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Hotel_name          426 non-null    object
#  1   Cities              426 non-null    object
#  2   Location            426 non-null    object
#  3   No_of_reviews       426 non-null    int64
#  4   User_ratings        426 non-null    float64
#  5   Star_Rating         426 non-null    float64
#  6   Review_score        426 non-null    object
#  7   Restaurant          426 non-null    object
#  8   Bar                 426 non-null    object
#  9   Heating             426 non-null    object
#  10  Lift                426 non-null    object
#  11  Breakfast_Cuisine1  426 non-null    object
#  12  Breakfast_Cuisine2  426 non-null    object
#  13  Breakfast_Cuisine3  426 non-null    object
#  14  Free_wifi           426 non-null    object
# ...

# %% [markdown]
# From the above we can observe, out of 21 features 17 features are of object datatype, 2 features are float data type , 2 feature is of int datatype.

# %% [markdown]
# Let's check for statistical information of the data.

# %%
df.describe()
# Out:
#        No_of_reviews  User_ratings  Star_Rating           Price
# count     426.000000    426.000000   426.000000      426.000000
# mean     9517.267606      8.993897     7.956338    25338.223005
# std      6095.652267      0.442464     0.701172    56414.453551
# min      1753.000000      7.500000     5.600000     2393.000000
# 25%      5662.000000      8.700000     7.600000    11088.000000
# 50%      8493.000000      9.000000     8.100000    17202.500000
# 75%     11343.000000      9.400000     8.400000    26940.750000
# max     38510.000000      9.700000     9.100000  1000000.000000

# %% [markdown]
# From the above we can observe, for feature 'Price' mean is greater than 50% data. So data for this feature is right skewed.
#
# For feature No_of_reviews mean is greater than 50% data. So, data for this feature is right skewed.

# %% [markdown]
# Let's check for graphical view of the data.

# %%
sns.countplot('Family_rooms',data=df)
plt.show()

# %% [markdown]
# From the above we can observe there are more number of hotels with Family rooms.

# %%
sns.countplot('Restaurant',data=df)
plt.show()

# %% [markdown]
# From the above we can observe, there are very less number of hotels which does not contain Restaurant.

# %%
sns.countplot('Bar',data=df)
plt.show()

# %% [markdown]
# From the above we can observe, there are very less number of hotels which does not contain Bar.

# %%
sns.countplot('Heating',data=df)
plt.show()

# %% [markdown]
# From the above we can observe, almost all hotels contains Heating and a range of 130 to 150 hotels does not contain Heating.

# %%
sns.countplot('Lift',data=df)
plt.show()

# %%
df['Lift'].value_counts()
# Out:
# Yes    424
# No       2
# Name: Lift, dtype: int64

# %% [markdown]
# From the above we can observe, almost all hotels contain Lift. Only 2 hotels does not contain Lift.

# %%
sns.countplot('Single_Bed',data=df)
plt.show()

# %% [markdown]
# From the above we can observe, there are very less number of hotels that contain single bed.

# %%
sns.countplot('Double_Bed',data=df)
plt.show()

# %% [markdown]
# From the above we can observe, there are very less number of hotels that does not contain double bed.

# %%
df.columns
# Out:
# Index(['Hotel_name', 'Cities', 'Location', 'No_of_reviews', 'User_ratings',
#        'Star_Rating', 'Review_score', 'Restaurant', 'Bar', 'Heating', 'Lift',
#        'Breakfast_Cuisine1', 'Breakfast_Cuisine2', 'Breakfast_Cuisine3',
#        'Free_wifi', 'Family_rooms', 'Non-smoking rooms', 'Room_Type',
#        'Single_Bed', 'Double_Bed', 'Price'],
#       dtype='object')

# %%
plt.figure(figsize=(12,8))
sns.stripplot(x='Cities',y='User_ratings',data=df)
plt.show()

# %% [markdown]
# From the above we can observe, Paris city has less User ratings and Kuala Lumpur has high User ratings.

# %%
plt.figure(figsize=(12,8))
sns.stripplot(x='Cities',y='Star_Rating',data=df)
plt.show()

# %% [markdown]
# From the above we can observe, Dubai and Sydney has high Star rating. New delhi has hotels with less star rating .

# %%
plt.figure(figsize=(12,8))
sns.stripplot(x='Cities',y='Review_score',data=df)
plt.show()

# %%
plt.figure(figsize=(12,5))
sns.stripplot(x='Cities',y='Price',data=df)
plt.show()

# %% [markdown]
# From the above we can observe, Price of hotel rooms of all cities are almost in same range, except in Delhi. In Delhi, there are very few hotels having high room price.

# %%
plt.figure(figsize=(12,5))
sns.stripplot(x='Cities',y='No_of_reviews',data=df)
plt.show()

# %% [markdown]
# From the above we can observe, Dubai is having high reviews and nect london is having high reviews. Torornto is having less number of reviews.

# %%
categorical_cols=[]
numerical_cols=[]

cols=df.columns

for i in cols:
    if(df[i].dtype== object):
        categorical_cols.append(i)
        
    else:
        numerical_cols.append(i)
        
        
print(categorical_cols)
print(numerical_cols)
# Out:
# ['Hotel_name', 'Cities', 'Location', 'Review_score', 'Restaurant', 'Bar', 'Heating', 'Lift', 'Breakfast_Cuisine1', 'Breakfast_Cuisine2', 'Breakfast_Cuisine3', 'Free_wifi', 'Family_rooms', 'Non-smoking rooms', 'Room_Type', 'Single_Bed', 'Double_Bed']
# ['No_of_reviews', 'User_ratings', 'Star_Rating', 'Price']

# %% [markdown]
# Let's encode categorical columns with the help of encoding techniques.

# %%
categorical_cols
# Out:
# ['Hotel_name',
#  'Cities',
#  'Location',
#  'Review_score',
#  'Restaurant',
#  'Bar',
#  'Heating',
#  'Lift',
#  'Breakfast_Cuisine1',
#  'Breakfast_Cuisine2',
#  'Breakfast_Cuisine3',
#  'Free_wifi',
#  'Family_rooms',
#  'Non-smoking rooms',
#  'Room_Type',
#  'Single_Bed',
#  'Double_Bed']

# %%
from sklearn.preprocessing import LabelEncoder
cols=['Cities','Family_rooms','Restaurant','Bar','Heating','Lift','Breakfast_Cuisine1','Breakfast_Cuisine2','Breakfast_Cuisine3','Free_wifi',
     'Non-smoking rooms','Single_Bed','Double_Bed','Hotel_name','Review_score','Room_Type']
LE=LabelEncoder()

for i in cols:
    df[i]=LE.fit_transform(df[i])
    
    
df
# Out:
#      Hotel_name  Cities                                           Location  \
# 0            13       1  Jumeirah Village Circle Dubai, Dubai, United A...
# 1            13       1  Jumeirah Village Circle Dubai, Dubai, United A...
# 2            13       1  Jumeirah Village Circle Dubai, Dubai, United A...
# 3            13       1  Jumeirah Village Circle Dubai, Dubai, United A...
# 4            13       1  Jumeirah Village Circle Dubai, Dubai, United A...
# ..          ...     ...                                                ...
# 421          12       9  925 Dixon Road, Etobicoke, M9W 1J8 Toronto, Ca...
# 422          12       9  925 Dixon Road, Etobicoke, M9W 1J8 Toronto, Ca...
# 423          12       9  925 Dixon Road, Etobicoke, M9W 1J8 Toronto, Ca...
# 424          23       9  970 Dixon Road, Etobicoke, M9W 1J9 Toronto, Ca...
# 425          23       9  970 Dixon Road, Etobicoke, M9W 1J9 Toronto, Ca...
#
# ...

# %%
print('Data after encoding')
print('------------------------')

for i in cols:
    print(df[i].value_counts())
    print('----------------------')
# Out:
# Data after encoding
# ------------------------
# 2    69
# 7    53
# 3    50
# 1    48
# 5    48
# 0    36
# 4    35
# 6    32
# 9    31
# 8    24
# Name: Cities, dtype: int64
# ----------------------
# 1    331
# 0     95
# Name: Family_rooms, dtype: int64
# ----------------------
# 1    345
# 0     81
# Name: Restaurant, dtype: int64
# ----------------------
# 1    334
# 0     92
# Name: Bar, dtype: int64
# ----------------------
# 1    321
# 0    105
# Name: Heating, dtype: int64
# ----------------------
# 1    424
# 0      2
# Name: Lift, dtype: int64
# ----------------------
# 2    272
# 5     73
# 6     22
# 3     20
# 0     16
# 1     15
# 4      8
# Name: Breakfast_Cuisine1, dtype: int64
# ----------------------
# 9    176
# 3     69
# 8     63
# 6     54
# 5     28
# 2     13
# 1     10
# 0      8
# 7      3
# 4      2
# Name: Breakfast_Cuisine2, dtype: int64
# ----------------------
# 7    213
# 6     82
# 1     34
# 2     26
# 4     24
# 5     20
# 3     17
# 0     10
# ...

# %%
df.head()
# Out:
#    Hotel_name  Cities                                           Location  \
# 0          13       1  Jumeirah Village Circle Dubai, Dubai, United A...
# 1          13       1  Jumeirah Village Circle Dubai, Dubai, United A...
# 2          13       1  Jumeirah Village Circle Dubai, Dubai, United A...
# 3          13       1  Jumeirah Village Circle Dubai, Dubai, United A...
# 4          13       1  Jumeirah Village Circle Dubai, Dubai, United A...
#
#    No_of_reviews  User_ratings  Star_Rating  Review_score  Restaurant  Bar  \
# 0          38510           9.3          9.1             4           1    1
# 1          38510           9.3          9.1             4           1    1
# 2          38510           9.3          9.1             4           1    1
# 3          38510           9.3          9.1             4           1    1
# 4          38510           9.3          9.1             4           1    1
#
# ...

# %% [markdown]
# As per my analysis Location is not required for predicting target feature. Let's drop these features.

# %%
df.drop(columns=['Location'],axis=1,inplace=True)

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# # Predicting Price

# %%
df4=df

plt.figure(figsize=(15,10))
n=1

for i in numerical_cols:
    ax=plt.subplot(2,3,n)
    sns.distplot(x=df4[i])
    plt.xlabel(i)
    n=n+1
    
plt.show()

# %% [markdown]
# From the above we can skewness is present in all the features. Let's check skew value.

# %%
df4[numerical_cols].skew()
# Out:
# No_of_reviews     2.356392
# User_ratings     -0.605601
# Star_Rating      -1.133978
# Price            14.152533
# dtype: float64

# %% [markdown]
# From the above we can observe skeweness value for all numerical features are not in range. Since 'Price' feature is target feature we will not perform any operation for reducing skeweness.
#
# Skew value for other features can be reduced with the help of transformation techniques.

# %%
df4['No_of_reviews']=np.cbrt(df4['No_of_reviews'])
df4['No_of_reviews']=np.cbrt(df4['No_of_reviews'])
df4['No_of_reviews']=np.cbrt(df4['No_of_reviews'])

df[numerical_cols].skew()
# Out:
# No_of_reviews     0.234183
# User_ratings     -0.605601
# Star_Rating      -1.133978
# Price            14.152533
# dtype: float64

# %% [markdown]
# After applying transformation techniques, only No_of_reviews feature skew value is reduced.
#
# If we are applying transformation techniques, skewness value is getting increased. Let's continue further without transforming data.

# %% [markdown]
# Let's check for outliers in the dataset.

# %%
plt.figure(figsize=(15,10))
n=1

for i in numerical_cols:
    ax=plt.subplot(2,3,n)
    sns.boxplot(y=df4[i])
    plt.xlabel(i)
    n=n+1
    
plt.show()

# %% [markdown]
# From the above we can observe outliers are present in all numerical features. Since, Price is target featute let's not remove outliers from this feature.
#
# Let's remove outliers with the help of zscore technique.

# %%
from scipy.stats import zscore

df5=pd.DataFrame()

zscore=np.abs(zscore(df4[['User_ratings','Star_Rating','No_of_reviews']]))

df5=df4[(zscore<3).all(axis=1)]

# %%
df5.shape
# Out:
# (411, 20)

# %%
df4.shape
# Out:
# (426, 20)

# %% [markdown]
# Let' check correlation among features.

# %%
plt.figure(figsize=(20,20))

sns.heatmap(df5.corr(),annot=True,fmt='.2f')
plt.show()

# %% [markdown]
# Below are the observations from heatmap,
#
# - User ratings and star ratings are highly correlated with each other.
#
# - Single Bed and Double bed are highly negatively correlated with each other.

# %% [markdown]
# - Let's drop User rating because it's correlation value with Price is less compared with Star Rating.
#
# - Let's drop Double Bed because it's correlation value with Price is less compared with Single Bed.

# %%
df5.drop(columns=['Double_Bed','User_ratings'],axis=1,inplace=True)

# %% [markdown]
# Let's check for VIF value .

# %%
x=df5.drop('Price',axis=1)
y=df5["Price"]

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

scaler=StandardScaler()
x_scaled=scaler.fit_transform(x)

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

VIF=pd.DataFrame()
VIF['features']=x.columns
VIF['value']=[variance_inflation_factor(x_scaled,i) for i in range(x.shape[1])]
VIF
# Out:
#               features     value
# 0           Hotel_name  1.192649
# 1               Cities  2.200469
# 2        No_of_reviews  1.663989
# 3          Star_Rating  1.513343
# 4         Review_score  1.570006
# 5           Restaurant  1.738389
# 6                  Bar  1.469293
# 7              Heating  2.089019
# 8                 Lift  1.101430
# 9   Breakfast_Cuisine1  1.377911
# 10  Breakfast_Cuisine2  1.396539
# 11  Breakfast_Cuisine3  1.780141
# 12           Free_wifi  1.239621
# 13        Family_rooms  1.156736
# 14   Non-smoking rooms  1.192656
# 15           Room_Type  1.084343
# 16          Single_Bed  1.329771

# %% [markdown]
# From the above we can observe Vif value of all features are in range.
#
# Let's continue further model building.

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
from sklearn.model_selection import train_test_split

# %%
max_rvalue=0
max_randstate=0
for i in range(1,200):
    x_train,x_test,y_train,y_test=train_test_split(x_scaled,y,test_size=0.25,random_state=i)
    LR=LinearRegression()
    LR.fit(x_train,y_train)
    y_predict=LR.predict(x_test)
    r_value=r2_score(y_test,y_predict)
    if(r_value>max_rvalue):
        max_rvalue=r_value
        max_randstate=i
        
    
print('Best random state : ',max_randstate) 
print('r2 score :',max_rvalue)
# Out:
# Best random state :  115
# r2 score : 0.1808407935048585

# %%
x_train,x_test,y_train,y_test=train_test_split(x_scaled,y,test_size=0.25,random_state=115)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor,ExtraTreeRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.linear_model import Lasso,Ridge
from sklearn.ensemble import RandomForestRegressor

# %%
LR=LinearRegression()
LR.fit(x_train,y_train)
y_predict_LR=LR.predict(x_test)
r_value_LR=r2_score(y_test,y_predict_LR)
print("R2 score - ",r_value_LR)
# Out:
# R2 score -  0.1808407935048585

# %%
DTR=DecisionTreeRegressor()
DTR.fit(x_train,y_train)
y_predict_DTR=DTR.predict(x_test)
r_value_DTR=r2_score(y_test,y_predict_DTR)
print("R2 score - ",r_value_DTR)
# Out:
# R2 score -  0.08654924730200309

# %%
KNR=KNeighborsRegressor()
KNR.fit(x_train,y_train)
y_predict_KNR=KNR.predict(x_test)
r_value_KNR=r2_score(y_test,y_predict_KNR)
print('R2 score - ',r_value_KNR)
# Out:
# R2 score -  0.5725948456549836

# %%
RFR=RandomForestRegressor()
RFR.fit(x_train,y_train)
y_predict_RFR=RFR.predict(x_test)
r_value_RFR=r2_score(y_test,y_predict_RFR)
print('R2 score - ',r_value_RFR)
# Out:
# R2 score -  0.0675828945292627

# %%
L=Lasso()
L.fit(x_train,y_train)
y_predict_L=L.predict(x_test)
r_value_L=r2_score(y_test,y_predict_L)
print('R2 score - ',r_value_L)
# Out:
# R2 score -  0.18081908889996567

# %%
R=Ridge()
R.fit(x_train,y_train)
y_predict_R=R.predict(x_test)
r_value_R=r2_score(y_test,y_predict_R)
print('R2 score - ',r_value_R)
# Out:
# R2 score -  0.18044098095272187

# %%
ETR=ExtraTreeRegressor()
ETR.fit(x_train,y_train)
y_predict_ETR=ETR.predict(x_test)
r_value_ETR=r2_score(y_test,y_predict_ETR)
print('R2 score ',r_value_ETR)
# Out:
# R2 score  0.06536098926426914

# %% [markdown]
# Let's check cross validation score of the models.

# %%
from sklearn.model_selection import cross_val_score

# %%
score=cross_val_score(LR,x,y)
print("cross validation score is ", r_value_LR-score.mean())
# Out:
# cross validation score is  9.004118986376543

# %%
score=cross_val_score(DTR,x,y)
print("Difference is ",r_value_DTR-score.mean())
# Out:
# Difference is  27.112233387935827

# %%
score=cross_val_score(KNR,x,y)
print("Difference is ",r_value_KNR-score.mean())
# Out:
# Difference is  5.151345277364077

# %%
score=cross_val_score(L,x,y)
print("Difference is ",r_value_L-score.mean())
# Out:
# Difference is  8.97625872184506

# %%
score=cross_val_score(R,x,y)
print("Difference is ",r_value_R-score.mean())
# Out:
# Difference is  6.831155393968191

# %%
score=cross_val_score(RFR,x,y)
print("Difference is ",r_value_RFR-score.mean())
# Out:
# Difference is  8.998309979991184

# %%
score=cross_val_score(ETR,x,y)
print("Difference is ",r_value_ETR-score.mean())
# Out:
# Difference is  27.324466762392838

# %% [markdown]
# From the above we can observe, cross val score of KNeighborsRefressor is less compared to other models. Let's consider this as best model for the dataset.
#
# Let's generate MAE,MSE,RMSE.

# %%
from sklearn.metrics import mean_absolute_error,mean_squared_error
print("Mean Absolute Error ",mean_absolute_error(y_test,y_predict_KNR))
print("Mean Squared Error ",mean_squared_error(y_test,y_predict_KNR))
print("Root mean squared error ",np.sqrt(mean_squared_error(y_test,y_predict_KNR)))
# Out:
# Mean Absolute Error  13308.93786407767
# Mean Squared Error  1330564663.3565047
# Root mean squared error  36476.905890666014

# %% [markdown]
# Let's tune parameter and try to increase r2 score of the models.

# %%
from sklearn.model_selection import GridSearchCV

# %%
param_grid={ 'n_neighbors' : [5,7,9,11,13,15],
               'weights' : ['uniform','distance'],
               'metric' : ['minkowski','euclidean','manhattan'],
               'algorithm':['auto', 'ball_tree', 'kd_tree', 'brute'],
               'leaf_size':[20,25,30,34]
           }

# %%
GSV=GridSearchCV(KNR,param_grid=param_grid,n_jobs=-1)
GSV.fit(x_train,y_train)
GSV.best_params_
# Out:
# {'algorithm': 'auto',
#  'leaf_size': 20,
#  'metric': 'minkowski',
#  'n_neighbors': 13,
#  'weights': 'uniform'}

# %%
Best_model=KNeighborsRegressor(algorithm='auto',leaf_size=30,weights='uniform')
Best_model.fit(x_train,y_train)
y_predict_final=Best_model.predict(x_test)
r_value=r2_score(y_test,y_predict_final)
print(r_value)
# Out:
# 0.5725948456549836

# %% [markdown]
# After trying multiple values for parameters of the model, r2 score value is not increased.

# %%
print("Mean Absolute Error ",mean_absolute_error(y_test,y_predict))
print("Mean Squared Error ",mean_squared_error(y_test,y_predict))
print("Root mean squared error ",np.sqrt(mean_squared_error(y_test,y_predict)))
# Out:
# Mean Absolute Error  27429.83937903525
# Mean Squared Error  3948787654.9654
# Root mean squared error  62839.37981047713

# %%
# Predicting Review score (Classification)

# %%
df6=df

plt.figure(figsize=(15,10))
n=1

for i in numerical_cols:
    ax=plt.subplot(2,3,n)
    sns.distplot(x=df6[i])
    plt.xlabel(i)
    n=n+1
    
plt.show()

# %%
df6[numerical_cols].skew()
# Out:
# No_of_reviews     0.234183
# User_ratings     -0.605601
# Star_Rating      -1.133978
# Price            14.152533
# dtype: float64

# %% [markdown]
# From the above we can observe all feature skew value is in range. Let's reduce skewness with the help of transformation techniques.

# %%
df6['No_of_reviews']=np.cbrt(df6['No_of_reviews'])
df6['No_of_reviews']=np.cbrt(df6['No_of_reviews'])


df6['Price']=np.cbrt(df6['Price'])
df6['Price']=np.cbrt(df6['Price'])
df6['Price']=np.cbrt(df6['Price'])
df6['Price']=np.cbrt(df6['Price'])

df6[numerical_cols].skew()
# Out:
# No_of_reviews    0.170168
# User_ratings    -0.605601
# Star_Rating     -1.133978
# Price            0.781873
# dtype: float64

# %% [markdown]
# After applying transformation techniques, skew value of No_of_reviews reduced to normal range and skew value for Price reduced to 0.72.
#
# Skew value for User_ratings and Star_rating is getting increased, so continuing further without transforming data of these features.

# %%
plt.figure(figsize=(15,10))
n=1

for i in numerical_cols:
    ax=plt.subplot(2,3,n)
    sns.boxplot(y=df6[i])
    plt.xlabel(i)
    n=n+1
    
plt.show()

# %% [markdown]
# From the above we can observe outliers are present in all features. Let's remove outliers with the help of zscore technique.

# %%
from scipy.stats import zscore

zscore=np.abs(zscore(df6[numerical_cols]))

df7=df6[(zscore<3) . all(axis=1)]

df7.shape
# Out:
# (408, 20)

# %%
df6.shape
# Out:
# (426, 20)

# %% [markdown]
# Let's plot heatmap and check the correlation among features.

# %%
plt.figure(figsize=(20,20))
sns.heatmap(df7.corr(),annot=True,fmt='.2f')
plt.show()

# %% [markdown]
# Below are the observations from heatmap,
#
# - Single bed, Double bed are higly negatively correlated with each other.
#
# - User ratings, star ratings are higly correlated with eachother.
#
# Let's drop Single bed because Double bed is more correlated than single bed.
#
# Let's drop user ratings because its correlation value is less compared to star ratings.

# %%
df7.drop(columns=['User_ratings','Double_Bed'],axis=1,inplace=True)

df7.shape
# Out:
# (408, 18)

# %% [markdown]
# Let's check for VIF value.

# %%
from sklearn.preprocessing import StandardScaler

x=df7.drop('Review_score',axis=1)

y=df7['Review_score']

scaler=StandardScaler()

x_scaled=scaler.fit_transform(x)

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

Vif=pd.DataFrame()

Vif['features']=x.columns

Vif['value']=[variance_inflation_factor(x_scaled,i) for i in range(x.shape[1])]

Vif
# Out:
#               features     value
# 0           Hotel_name  1.190159
# 1               Cities  2.249914
# 2        No_of_reviews  1.649763
# 3          Star_Rating  1.605644
# 4           Restaurant  1.601450
# 5                  Bar  1.471027
# 6              Heating  2.110762
# 7                 Lift  1.104431
# 8   Breakfast_Cuisine1  1.393916
# 9   Breakfast_Cuisine2  1.273070
# 10  Breakfast_Cuisine3  1.757843
# 11           Free_wifi  1.206053
# 12        Family_rooms  1.211461
# 13   Non-smoking rooms  1.188858
# 14           Room_Type  1.108505
# 15          Single_Bed  1.169448
# 16               Price  1.679006

# %% [markdown]
# From the above we can observe Vif value of all features are in range.

# %%
y.value_counts()
# Out:
# 5    170
# 1    139
# 0     62
# 3     19
# 4     18
# Name: Review_score, dtype: int64

# %% [markdown]
# Let's find best Random state.

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

# %%
max_acc=0
max_rand_state=0
for i in range(1,150):
    x_train,x_test,y_train,y_test=train_test_split(x_scaled,y,test_size=0.30,random_state=i)
    RFC=RandomForestClassifier()
    RFC.fit(x_train,y_train)
    y_predict=RFC.predict(x_test)
    acc_score=accuracy_score(y_test,y_predict)
    if(acc_score>max_acc):
        max_acc=acc_score
        max_rand_state=i
        
print("Best Random State - ",max_rand_state," Accuracy score - ",max_acc)
# Out:
# Best Random State -  1  Accuracy score -  1.0

# %%
x_train,x_test,y_train,y_test=train_test_split(x_scaled,y,test_size=0.30,random_state=1)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import AdaBoostClassifier,GradientBoostingClassifier,BaggingClassifier,RandomForestClassifier,ExtraTreesClassifier

# %%
LR=LogisticRegression()
LR.fit(x_train,y_train)
y_predict_LR=LR.predict(x_test)
acc_score_LR=accuracy_score(y_test,y_predict_LR)
print("Accuracy Score ",acc_score_LR)
# Out:
# Accuracy Score  0.9512195121951219

# %%
DTC=DecisionTreeClassifier()
DTC.fit(x_train,y_train)
y_predict_DTC=DTC.predict(x_test)
acc_score_DTC=accuracy_score(y_test,y_predict_DTC)
print("Accuracy Score ",acc_score_DTC)
# Out:
# Accuracy Score  1.0

# %%
Knn=KNeighborsClassifier()
Knn.fit(x_train,y_train)
y_predict_Knn=Knn.predict(x_test)
acc_score_Knn=accuracy_score(y_test,y_predict_Knn)
print("Accuracy Score ",acc_score_Knn)
# Out:
# Accuracy Score  0.9105691056910569

# %%
ABC=AdaBoostClassifier()
ABC.fit(x_train,y_train)
y_predict_ABC=ABC.predict(x_test)
acc_score_ABC=accuracy_score(y_test,y_predict_ABC)
print("Accuracy Score ",acc_score_ABC)
# Out:
# Accuracy Score  0.8536585365853658

# %%
GDT=GradientBoostingClassifier()
GDT.fit(x_train,y_train)
y_predict_GDT=GDT.predict(x_test)
acc_score_GDT=accuracy_score(y_test,y_predict_GDT)
print("Accuracy Score ",acc_score_GDT)
# Out:
# Accuracy Score  1.0

# %%
BC=BaggingClassifier()
BC.fit(x_train,y_train)
y_predict_BC=BC.predict(x_test)
acc_score_BC=accuracy_score(y_test,y_predict_BC)
print('Accuracy Score ',acc_score_BC)
# Out:
# Accuracy Score  1.0

# %%
RFC=RandomForestClassifier()
RFC.fit(x_train,y_train)
y_predict_RFC=RFC.predict(x_test)
acc_score_RFC=accuracy_score(y_test,y_predict_RFC)
print("accuracy score :",acc_score_RFC)
# Out:
# accuracy score : 1.0

# %%
ETC=ExtraTreesClassifier()
ETC.fit(x_train,y_train)
y_predict_ETC=ETC.predict(x_test)
acc_score_ETC=accuracy_score(y_test,y_predict_ETC)
print("Accuracy Score ",acc_score_ETC)
# Out:
# Accuracy Score  1.0

# %% [markdown]
# From the above we can observe, RandomForestClassifier, Bagging Classifier, GradientBoostingClassifier, DecisionTreeClassifier exhibits highest accuracy score. Let's check accuracy score provided by these models are due to overfitting of the model.
#
# This can be check with the help of cross validation score.

# %%
from sklearn.model_selection import cross_val_score
from sklearn.metrics import confusion_matrix,classification_report

# %%
score=cross_val_score(RFC,x,y)
mean=score.mean()
print("Difference is ",acc_score_RFC-mean)
# Out:
# Difference is  0.04164408310749779

# %%
score=cross_val_score(LR,x,y)
mean=score.mean()
print("Difference is ",acc_score_LR-mean)
# Out:
# Difference is  0.5271303824149353

# %%
score=cross_val_score(Knn,x,y)
mean=score.mean()
print("Difference is ",acc_score_Knn-mean)
# Out:
# Difference is  0.5109906654622102

# %%
score=cross_val_score(DTC,x,y)
mean=score.mean()
print("Difference is ",acc_score_DTC-mean)
# Out:
# Difference is  0.0

# %%
score=cross_val_score(ETC,x,y)
mean=score.mean()
print("Difference is ",acc_score_ETC-mean)
# Out:
# Difference is  0.098193315266486

# %%
score=cross_val_score(GDT,x,y)
mean=score.mean()
print("Difference is ",acc_score_GDT-mean)
# Out:
# Difference is  0.0

# %%
score=cross_val_score(ABC,x,y)
mean=score.mean()
print("Difference is ",acc_score_ABC-mean)
# Out:
# Difference is  0.0056007226738933324

# %%
score=cross_val_score(BC,x,y)
mean=score.mean()
print("Difference is ",acc_score_BC-mean)
# Out:
# Difference is  0.0

# %% [markdown]
# From the above we can observe, Bagging classifier, GradientBoostingClassifier, DecisionTreeClassifier has less cross validation score when compared with other models.
#
# Let's generate classification report and confusion matrix.

# %%
print("Confusion Matrix \n",confusion_matrix(y_test,y_predict_BC))
# Out:
# Confusion Matrix
#  [[18  0  0  0  0]
#  [ 0 39  0  0  0]
#  [ 0  0  7  0  0]
#  [ 0  0  0  7  0]
#  [ 0  0  0  0 52]]

# %%
print("Classification Report \n",classification_report(y_test,y_predict_BC))
# Out:
# Classification Report
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        18
#            1       1.00      1.00      1.00        39
#            3       1.00      1.00      1.00         7
#            4       1.00      1.00      1.00         7
#            5       1.00      1.00      1.00        52
#
#     accuracy                           1.00       123
#    macro avg       1.00      1.00      1.00       123
# weighted avg       1.00      1.00      1.00       123

# %%
print("Confusion Matrix \n",confusion_matrix(y_test,y_predict_GDT))
# Out:
# Confusion Matrix
#  [[18  0  0  0  0]
#  [ 0 39  0  0  0]
#  [ 0  0  7  0  0]
#  [ 0  0  0  7  0]
#  [ 0  0  0  0 52]]

# %%
print("Classification Report \n",classification_report(y_test,y_predict_GDT))
# Out:
# Classification Report
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        18
#            1       1.00      1.00      1.00        39
#            3       1.00      1.00      1.00         7
#            4       1.00      1.00      1.00         7
#            5       1.00      1.00      1.00        52
#
#     accuracy                           1.00       123
#    macro avg       1.00      1.00      1.00       123
# weighted avg       1.00      1.00      1.00       123

# %%
print("Confusion Matrix \n",confusion_matrix(y_test,y_predict_DTC))
# Out:
# Confusion Matrix
#  [[18  0  0  0  0]
#  [ 0 39  0  0  0]
#  [ 0  0  7  0  0]
#  [ 0  0  0  7  0]
#  [ 0  0  0  0 52]]

# %%
print("Classification Report \n",classification_report(y_test,y_predict_DTC))
# Out:
# Classification Report
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        18
#            1       1.00      1.00      1.00        39
#            3       1.00      1.00      1.00         7
#            4       1.00      1.00      1.00         7
#            5       1.00      1.00      1.00        52
#
#     accuracy                           1.00       123
#    macro avg       1.00      1.00      1.00       123
# weighted avg       1.00      1.00      1.00       123
